# %%
# Visualize ALL 6 sensors
fig, axes = plt.subplots(3, 2, figsize=(15, 11))

# CO2
axes[0, 0].plot(sensor_data.index, sensor_data['CO2_ppm'], 'b-', linewidth=2, marker='o', markersize=4)
axes[0, 0].set_title('1. MQ135 - CO2 Sensor', fontsize=13, fontweight='bold')
axes[0, 0].set_ylabel('CO2 (ppm)')
axes[0, 0].grid(True, alpha=0.3)

# Temperature
axes[0, 1].plot(sensor_data.index, sensor_data['Temperature_C'], 'r-', linewidth=2, marker='o', markersize=4)
axes[0, 1].set_title('2. DHT22 - Temperature', fontsize=13, fontweight='bold')
axes[0, 1].set_ylabel('Temperature (°C)')
axes[0, 1].grid(True, alpha=0.3)

# Humidity
axes[1, 0].plot(sensor_data.index, sensor_data['Humidity_Percent'], 'g-', linewidth=2, marker='o', markersize=4)
axes[1, 0].set_title('3. DHT22 - Humidity', fontsize=13, fontweight='bold')
axes[1, 0].set_ylabel('Humidity (%)')
axes[1, 0].grid(True, alpha=0.3)

# FLOW SENSOR
axes[1, 1].plot(sensor_data.index, sensor_data['Gas_Flow_L_per_min'], 'cyan', linewidth=2.5, marker='o', markersize=4)
axes[1, 1].set_title('4. YF-S201 - FLOW SENSOR ← KEY!', fontsize=13, fontweight='bold', color='darkblue')
axes[1, 1].set_ylabel('Gas Flow (L/min)', fontsize=12, fontweight='bold')
axes[1, 1].grid(True, alpha=0.3)

# Weight
axes[2, 0].plot(sensor_data.index, sensor_data['Weight_Change_g'], 'orange', linewidth=2, marker='o', markersize=4)
axes[2, 0].set_title('5. Load Cell - Weight', fontsize=13, fontweight='bold')
axes[2, 0].set_ylabel('Weight (g)')
axes[2, 0].set_xlabel('Reading #')
axes[2, 0].grid(True, alpha=0.3)

# Fan
axes[2, 1].plot(sensor_data.index, sensor_data['Fan_Speed_RPM'], 'purple', linewidth=2, marker='o', markersize=4)
axes[2, 1].set_title('6. PWM - Fan Speed', fontsize=13, fontweight='bold')
axes[2, 1].set_ylabel('Speed (RPM)')
axes[2, 1].set_xlabel('Reading #')
axes[2, 1].grid(True, alpha=0.3)

plt.suptitle('ALL 6 SENSORS', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# Show correlation between fan and flow
plt.figure(figsize=(10, 6))
plt.scatter(sensor_data['Fan_Speed_RPM'], sensor_data['Gas_Flow_L_per_min'],
            s=100, alpha=0.6, c='blue', edgecolors='black')
plt.xlabel('Fan Speed (RPM)', fontsize=13, fontweight='bold')
plt.ylabel('Gas Flow Rate (L/min) ← FLOW SENSOR', fontsize=13, fontweight='bold')
plt.title('Fan-Flow Correlation (Physical Consistency Check)', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

print("All 6 sensors visualized (FLOW SENSOR INCLUDED!)")
