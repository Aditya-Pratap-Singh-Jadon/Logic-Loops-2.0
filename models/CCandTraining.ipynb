# %%
#phase 12
pipeline = CarbonCapturePipeline(
    enterprise_id="ENTERPRISE_001",
    is_msme=True
)
train_size = int(len(sensor_data) * 0.7)
train_data = sensor_data.iloc[:train_size]
test_data = sensor_data.iloc[train_size:]

print(f"Training: {len(train_data)} records")
print(f"Testing: {len(test_data)} records")

pipeline.train_models(train_data)
