# %%
#Processing Results
results = pipeline.process_batch(test_data)

print("\n📊 RESULTS (SHOWING FLOW SENSOR DATA):")
print(results[['Record_ID', 'CO2_ppm', 'Gas_Flow_L_min', 'Weight_g',
               'Fvalid', 'Credits', 'Tokens', 'Value_INR']])

#Analysis
print("\n" + "=" * 70)
print("ANALYSIS (WITH FLOW SENSOR)")
print("=" * 70)

print(f"\n📊 PROCESSING:")
print(f"   Records: {len(results)}")
print(f"   Normal: {(~results['Is_Anomaly']).sum()}")
print(f"   Anomalies: {results['Is_Anomaly'].sum()}")
print(f"   Avg Fvalid: {results['Fvalid'].mean():.4f}")

print(f"\n🌊 FLOW SENSOR STATS:")
print(f"   Avg Flow: {results['Gas_Flow_L_min'].mean():.2f} L/min")
print(f"   Flow Range: {results['Gas_Flow_L_min'].min():.2f} - {results['Gas_Flow_L_min'].max():.2f} L/min")

print(f"\n💰 CREDITS:")
total_credits = results['Credits'].sum()
total_value = results['Value_INR'].sum()
print(f"   Total: {total_credits:.6f} tonnes CO2")
print(f"   Value: ₹{total_value:,.2f}")

print(f"\n🪙 TOKENS:")
print(f"   Minted: {results['Tokens'].sum():.6f} CUBEX")

print("=" * 70)
